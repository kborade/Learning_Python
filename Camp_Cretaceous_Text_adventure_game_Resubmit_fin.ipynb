# %%
#
"""
Created on Monday 25th 2021
@KBorade

"""
"""
Docstring


                                    Welcome to 'Jurassic World : Camp Cretaceous'
Introduction

This game is based on a Netflix series of the same name (2020).

The game follows the adventure of 6 teenagers in the Jurrasic world and is staged in 3 days.

It is divided into 17 functions including 2 loose and 2 win scenarios. 

This game is a survival game. Every crossroad has a different ending. So the player gets intrigued to play it again.

References
-dinosaurus photos- https://www.asciiart.eu/animals/reptiles/dinosaurs
-https://asciiart.website/index.php?art=animals/reptiles/dinosaurs

 B) Known Bugs and/or Errors:
    None.

"""
import random

def intro():
    print(f"""   

{'#' * 120} 
                                        Welcome to 'Jurassic World : Camp Cretaceous'
{'#' * 120}     

     
              ,
               ,  ;:._.-`''.
             ;.;'.;`      _ `.
              ',;`       ( \ ,`-.  
           `:.`,         (_/ ;\  `-.
            ';:              / `.   `-._
          `;.;'              `-,/ .     `-.
          ';;'              _    `^`       `.
         ';;            ,'-' `--._          ;
':      `;;        ,;     `.    ':`,,.__,,_ /
 `;`:;`;:`       ,;  '.    ;,      ';';':';;`
              .,; '    '-._ `':.;    
            .:; `          '._ `';;,
          ;:` `    :'`'       ',__.)
        `;:;:.,...;'`'
      ';. '`'::'`''  .'`'
    ,'jgs`';;:,..::;`'`'
, .;`      `'::''`
,`;`.
                          
                          
>>>>>> This game is based on Netflix series of the same name. 
>>>>>> The game follows adventure of 6 teenagers (You, Jasmine, Kenji, Brooklyn, Sam, Ben)
>>>>>> You have received once in a lifetime opportunity to visit Isle Nublar:Camp Cretaceous.
>>>>>> However, once the dinosaurs get loose, you can only reply on each other for survival. 
>>>>>> So, every decision you make will lead to different result and ultimately you and your friend’s survival. 
>>>>>> Hope you have an adventure of your lifetime!!

P.S. – There are 2 alternate endings to this game. Hope you get explore both.
    
    """)
    input (prompt ="Press any key to continue.\n")
    
    day_0()

#Engaging the Players- Part 1
def day_0():

#While loop for name   
    name = input (prompt = "Enter your name.\n")
    name_cap = name.capitalize()
    x = len(name_cap)
    while x > 0:
        print(f"""Hi {name_cap}\n""")
        day_0_0()
        break
    else:
        print("Please enter your name.\n")
        day_0() # Return to day_0- Engaging the Players- Part 1
        
#Engaging the Players- Part 2        
def day_0_0():           
    Dino_Fact= input (prompt = "Wanna know a fun fact about dinosaurs?\n")
    
#Casefolding the user input
    Dino_Fact = Dino_Fact.capitalize()
    
#Conditional Statement for Dino_check  

    if Dino_Fact == 'Yes' or Dino_Fact == 'Y':
        answer_list = ['Did you know that the word Dinosaur means terrible lizard in Greek!\n',
                      'Did you know the dinaosaur with the longest name is micropachycephalosaurus which means little thick-headed lizard!\n',
                      'Did you know that reptiles and birds are the decendents of dianosaurs!\n']
        answer = random.choice(answer_list)
        print(answer)
        input (prompt = "Press enter to continue.\n")
        day_1() # go to day one
        
    elif Dino_Fact =='No' or Dino_Fact =='N' :
        print ("Thats too bad!\n")
        print ("But, I hope you enjoy this game!!!\n")
        day_1() # go to day one
        
    else:
        print("Invalid Answer. Please type yes or no.\n")
        day_0_0() # Return to day_0_0- Engaging the Players- Part 2
        
#****************************Constructing Day 1**************************************
#Day1 at camp.
def day_1():
    
    comment = random.randint(1,2)
       
    if comment == 1:
        print (f""" 
                                    *******************
                                    * Welcome to Day 1*
                                    *******************
    """)
    elif comment == 2:
         print (f""" 
                                    ------------------
                                   | Welcome to Day 1 |
                                    ------------------
    """)
    else:
        print("This function has bugs.")
    
    print (f"""
    
*********************************** Welcome to Isle Nublar **************************\n
...Your arrive at the dock late at night.\n
...Your guide Roxie and Hap take you to the camp.\n 
...You make frinds with other Kenji, Ben, Brooklyn, Jasmine and Sam..\n 
...You all are excited to explore the Jurassic Park.\n 
...It’s time for light-out.\n
...You go to bed or NOT.....\n
    """)
    
    input(prompt ="Press any key to continue.\n")
    
    print("...You hear something................\n ")
    
#Day 1 early morning-     
    print(f"""
...You check the time... It’s 3 o'clock in the morning.\n
...You can hear the compies running in the forest.\n 
    """)
    day_1_1() # Go to Day 1 Sneak out Sequence
    
#Day 1 Sneak out Sequence
def day_1_1():
    print("Do you wanna sneak out and see what's happening outside?\n")
    day_1_11 = input(prompt = "Type y/n.\n")
          
#Converting input to lower case
    day_1_11 = day_1_11.capitalize()
          
#Conditional statement- starts.
    if day_1_11 == 'Y' or day_1_11  == 'Yes' :
        
        print(f"""
...You arrive at a big cage. You can hear something in the cage.\n
...Kenji and brooklyn followed you.\n
...Brooklyn is trying to take video of the cage.\n
...Her phone falls in the cage. Kenji wants to retrive it.\n
...You try to stop him.\n
...He ignores you and climbs down into the cage.\n
...You saw something move inside the cage.\n
...You see what inside the cage.\n 
    """)
        
#User Input- Cross Road 1  - security/help    
        day_1_111 = input(prompt = f"""
What will you do?
    1. Help him get out of the compy cage.
    2. Call for security.
    Please enter a number.\n""")
        day_1_111 = day_1_111.capitalize()
    
    
#Nestted conditional statement.
        if day_1_111 =='1' or day_1_111 == 'Help' or day_1_111 =='One':
            print("...The raptor almost killed you and Kenji.\n")
            print("...As a punishment, you are grounded and cannot visit Dr. Wu's genetic lab.\n")
            day_1_3() # Go to ceratosaurus cage sequence
                
        elif day_1_111 =='2' or day_1_111 =='Call' or day_1_111 == 'Two':
            
            print (f"""
...Thankfully Kenji is unharmed.\n
...Roxie and Hap are furious with Kenji and ground him for a day.\n
""")
            input(prompt = "Press any key to continue.\n")
            
            print(f"""
...You go to Dr. Wu's lab.\n
...You get to see a baby Ankylosaurus hatch from the egg.\n
...You return to camp after an amazing day of watching dinosaurs and dino eggs.\n
""")
            print("""
            
       .----.
     .'  \__ '.
    |   __|  _ :
    V\/(0I0\/ |/
       \ : /  '
       (oYo)
       /` `\__
     _|  _ Vuu: ,
    |uV\/ \| \_/|
    :      /\   :
snd  \   -'    /
      '-.___.-'  <>
     =        <;
     """)
            day_2() # Go to Day 2 at Camp sequence
            
# End of Nested conditional statement
        else:
            print(" Invalid input. Please start over again.\n")
            day_1_1() # Day 1 Sneak out Sequence
            
    elif day_1_11 == 'N' or day_1_11 == 'No':
        print(f"""...You go back to sleep. It was a tiring day today.\n""")
        day_2() # Go to day 2 at Camp
        
#End of conditional statement        
    else:
        print("Invalid answer. Please enter 'y' or 'n'!\n")
        day_1_1() # Day 1 Sneak out Sequence

# Day 1 - Ceratosaurus cage sequence    
def day_1_3(): 
    
    print(f"""
...You are angry with Kenji for getting them in trouble.\n
...Kenji suggest sneaking out to see ceratosaurus.\n
...Kenji forgets the way and you end up INSIDE the cage.\n
""")
    print("What will you do?\n")
    
#User Input- Cross Road 2- Run/Hide    
    day_1_31 = input(prompt = "Run or Hide\n")
    
#Converting input to lower case.
    day_1_31 = day_1_31.lower()
    
#Conditional Statement starts. 
    if day_1_31 == 'run':
        
        print(f"""
...You somehow outran the dinosaur and are back to the camp before other campers return.\n
""")
        day_2()# Go to Day 2
        
    elif day_1_31 == 'hide':
        
        print("""
...You are scared, and you try to hide.\n 
...Ceratosaurus finds you.\n
The last thing you hear is Kenji calling your name.\n
""")
        fail() # fail sequence
#########################################################        
#End of a conditional statement.
    else:
        print("Invalid answer. Please read the question again.\n")
        day_1_3() # Restart Ceratosaurus cage sequence.
    
    
#******************************Constructing Day 2*********************************************
#Day 2 at Camp
def day_2():
    comment = random.randint(1,2)
       
    if comment == 1:
        print (f""" 
                                    *******************
                                    * Welcome to Day 2*
                                    *******************
    """)
    elif comment == 2:
         print (f""" 
                                    ------------------
                                   | Welcome to Day 2 |
                                    ------------------
    """)
    else:
        print("This function has bugs.")
    
    print(f"""
...Today is a beautiful day.\n
...You are going to help the dinosaurs move to grazing lands.\n
...But, an unexpected storm strikes.\n
...The thunder scares the dinosaurs and the start to run.\n 
...You see that a young Sinoceratops get separated from its herd.\n
        """)
    
#User Input-Cross Road 3- Help/stay
    day_21 = input(prompt = f"""
What will you wanna do?
    1. Try to help the Dinosaur.
    2. Stay with your friends and guide.
    Please enter a number.\n
          """)
    day_21 = day_21.lower()
    
#Conditional Statement          
    if day_21 == '1' or day_21 == 'one' or day_21 == 'try':
        
        print(f"""
...You decide to help Sinoceratops.\n
...You get separated from the group and get lost in jungle.\n 
...Baby sinocertops bumps into your gyrosphere.\n
...You are now stuck in mud.\n
...Your guide is very upset with you. You return to the camp.\n
""")
        day_3() # Go to Day 3 at camp
        
    elif day_21 == '2' or day_21 =='two' or day_21 == 'stay':
        print(f"""
...The other guide helped the dinosaur.\n
...Roxie ask you to help in taking care of dinosaur.\n
...You get to play with baby Brachiosaurus.\n
...You return to the camp after a mesmerizing day with dinosaur.\n
""")
        day_3() # Go to Day 3 at camp
            
#End of Conditional Statement
    else:
        print("Invalid entry. Please type a number.\n")
        day_2() # Restart Day 2 at camp
    
#*********************************Constructing Day 3*************************************
#Day 3 at camp
def day_3():
    comment = random.randint(1,2)
       
    if comment == 1:
        print (f""" 
                                    *******************
                                    * Welcome to Day 3*
                                    *******************
    """)
    elif comment == 2:
         print (f""" 
                                    ------------------
                                   | Welcome to Day 3 |
                                    ------------------
    """)
    else:
        print("This function has bugs.")
    
    print(f"""
...It's unnaturally quiet today.\n
...Roxie and hap went to meet Mr. Masarani(Owner of the Park) to update him about the camping activity.\n
...You look at the forest. \n
...Suddenly the light goes out.\n
...You hear a loud roar.\n
""")
    
#User Input- Cross Road 4- Stay/Run

    day_31 = input(prompt = f"""
What will you do?
    1.Stay in the camp
    2.Run in towards main park.\n""")
    day_31 = day_31.lower()
    
# Conditional statement.
    if day_31 == '1' or day_31 == 'one' or day_31 =='stay' or day_31 =='camp':
        print (f"""
...A huge unknown dinosaur is approaching their camp.\n
...Everyone is scared.\n
...The dinosaur is trying the climb up the metal pipes surrounding the building.\n
...You go towards the Ziplines and try to get to the other tower.\n
        """)
        day_3_1() # Go to Car Sequence.
        
    elif day_31 == '2' or day_31 == 'two' or day_31 =='run' or day_31 =='park':
        print(f"""
...You try to run towards the main park.\n
...You are running for your life.\n
...The last thing you hear is your friends scream.\n
        """)
        fail() # Go to fail Sequence
################################################3        
#end of conditional statement        
    else:
        print("Invalid input. Please answer again.\n")
        day_3() #Restart Day 3 at camp
        
#Day 3 -Car Sequence         
def day_3_1():
    print(f"""
...No one is in the tower.\n
...There is a car at the base of the tower. None of you can to drive!!!\n
    """)
    
# User Input Cross Road 5-go/stay
    day_3_11 = input(prompt= f"""
What will you do?
    1. GO to the car.
    2. STAY in the tower.
    Enter the 'GO' or 'STAY'
    """)

#Converting input to capitals
    day_3_11 = day_3_11.lower()
    
#Conditional statement starts
    if day_3_11 == 'go' or day_3_11 == '1' or day_3_11 == 'one':
        print(f"""
...Kenji drives as fast as he could.\n
...The Dominous rex is following you.\n
...Your car attracts Raptor.\n
...The Dominous Rex start to fight raptor and you get away.\n
""")
        day_3_2() # Got to Genetic Lab Sequence     
        
                
    elif day_3_11 == 'stay' or day_3_11 == '2' or day_3_11 == 'two':
        print(f"""
...You stay in the tower.
...The Dominous Rex claws its way into the building.\n
...You did not make it out of the building.\n
""")
        fail() # Go to fail Sequence
  #######################################3      
    else:
        print("Invalid Input. Please ready the question again.\n")
        day_3_1() # Restart Car Sequence
        
#Day 3- Genetic Lab Sequence  
def day_3_2():
    
    print(f"""
...You reach the genetic lab.\n
...The lab was deserted.\n
...Brooklyn reads the emergency notice -the last ferry will leave in 2 hours.\n
""")
    
#User Input- Cross Road 6- Stay/Leave
    day_3_21 = input(prompt = f"""
What will you do? 
STAY or LEAVE?
Type in your response.\n
""")
    
# Converting User Input to lower case.
    day_3_21 = day_3_21.lower()
    
    if day_3_21 == "stay":
        
        print(f"""
...You decide to stay in the genetic lab.\n
...Roxie and Hap came looking for you.\n
...They take you with them to the docks.\n
""")
        win() # Go to Win Sequence
        
    elif day_3_21 =="leave":
        print(f"""
...You decide to leave on your own.\n
...You take the car with you.\n
...The light of the car attracts the Pteranodons (the flying dinosaurs)\n
""")
        print(""" <\              _
                            \\          _/{
                     _       \\       _-   -_
                   /{        / `\   _-     - -_
                 _~  =      ( @  \ -        -  -_
               _- -   ~-_   \( =\ \           -  -_
             _~  -       ~_ | 1 :\ \      _-~-_ -  -_
           _-   -          ~  |V: \ \  _-~     ~-_-  -_
        _-~   -            /  | :  \ \            ~-_- -_
     _-~    -   _.._      {   | : _-``               ~- _-_
  _-~   -__..--~    ~-_  {   : \:}
=~__.--~~              ~-_\  :  /
                           \ : /__
                          //`Y'--\\      =
                         <+       \\
                          \\      WWW
                          MMM
                          
                          """)
        
#User Input- Cross Road 7- Run/Go Back/Tunnel
        day_3_22 = input (prompt = f"""
What will you do?
    1. Run into the forest.
    2. Try to get back to the lab.
    3. You try to get into the underground tunnel.
    Please enter a number. \n""")
        day_3_22 = day_3_22.lower()
        
#Nested Conditional
Statement 
        if day_3_22 == '1' or day_3_22 =='one':
        
            print(f"""
...You run into the forest.\n
...But there are two many of them.
...You don’t make it to shelter.\n
""")
            fail() # Go to fail Function
 ###########################3           
        elif day_3_22 == '2' or day_3_22 == 'two':
            print(f"""
...You return to the lab.\n
...Everyone is exhausted and hurt.\n
...Roxie and Hap came looking for you.\n
...They take you to the docks.\n
""")
            win() # Go to Win Function
            
        elif day_3_22 == '3' or day_3_22 =='three':
            print(f"""
...You made it to the underground tunnel.\n 
...The tunnel connecs to monorail.\n
...Everyone rejoice.\n
            """)
            day_3_3() # Go to Monorail Sequence
            
# End of nested conditional statement.
        else:
            print("Invalid entry. Please use number to answer the question.\n")
            day_3_2() # Restart Genetic Lab Sequence.          
        
    else:
        print("Please type in your response.\n")
        day_3_2() # Restart Genetic Lab Sequence

#Day 3- Monorail sequence
def day_3_3():
    
    print(f"""
...Kenji lead you to monorail.\n
...There is no power.\n
...Jasmine switches on the generators.\n
""")
 
    print(f"""
...You sat on the train.\n 
...you are gain attacked by Pteranodons.
...They got hold of Ben's leg.\n
""")
    print(""" <\              _
                            \\          _/{
                     _       \\       _-   -_
                   /{        / `\   _-     - -_
                 _~  =      ( @  \ -        -  -_
               _- -   ~-_   \( =\ \           -  -_
             _~  -       ~_ | 1 :\ \      _-~-_ -  -_
           _-   -          ~  |V: \ \  _-~     ~-_-  -_
        _-~   -            /  | :  \ \            ~-_- -_
     _-~    -   _.._      {   | : _-``               ~- _-_
  _-~   -__..--~    ~-_  {   : \:}
=~__.--~~              ~-_\  :  /
                           \ : /__
                          //`Y'--\\      =
                         <+       \\
                          \\      WWW
                          MMM
                          
                          """)
    
#User Input -Cross Road 8- Help/Not
    day_3_51 = input(prompt= f""" 
What will you do?
    1. Try to help.
    2. Do nothing.
    Please enter a number. \n """)
    day_3_51 = day_3_51.lower()
    
#Conditional Statement Starts
    if day_3_51 == '1' or day_3_51 =='one':
        print(f"""
...Jasmine switched off the lights on the train.\n
...You threw you shoe at them.\n
...They let go of his leg.\n
...But unfortunately, ben loses balance and falls off the train.\n
""")
        
#User Input - Cross Road 9- Stop/Not
        day_3_52 = input(prompt= f"""
Stop the train and help him? (Y/N)
""")
#Converting to Capital Case
        day_3_52 = day_3_52.capitalize()   

    #Nested Conditional statements.
        if day_3_52 =='Y' or day_3_52 =='Yes':
            print("...You stop the train and help Ben.\n")
            fail_1_1() # Go to Alternate Fail sequence.
 #####################################3       
        elif day_3_52 =='N' or day_3_52 == 'No':
            print(f"""
...You realize that you would not be able to help Ben. \n
...You reach the dock in time for the last ferry.\n
""")
            win_1_1() # Go to Alternate Win Sequence
        
        else:
            print("Invalid Entry. Please try again.\n")
            day_3_3() # Restart Monorail Sequence
        
    elif day_3_51 =='2' or day_3_51 == 'Two':
        print(f"""
...Pteranodons took Ben away.")\n
...You reached the docks in time for the last ferry.\n
""")
        win_1_1() # Go to Aternate Win function
    else:
        print("Invalid input. Please enter a number.\n")
        day_3_3() # Restart Monorail Sequence. 
    
# Fail sequence
def fail():
    print(f"""
.....You Lost......\n
.....GAME OVER.....\n
    """)

    
# Alternate fail Sequence
def fail_1_1():
    print(f"""
...You reached the docks.\n
...The ferry is long gone.\n
...You are stuck on this island full of dinosaurs.\n
.....You Lost......\n

.....GAME OVER.....\n

..Thank you for playing..\n
    """)
    


# Win Sequence
def win():
    
    print(f"""
    
...Congratulations!!!!! You Win!!!\n
    
...You get to the mainland safely.\n

.....GAME OVER.....

..Thank you for playing..\n""")

    
# Alternate Win Sequence
def win_1_1():
    
    print(f"""
...You Won. But you lost a friend.......\n
    
...With a heavy heart you go back to the mainland.\n

.....GAME OVER.....

..Thank you for playing..\n""")

        
intro()
# Out:
#   File "<tokenize>", line 540
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level
